# %%
from bootcamp.databricks_compat import display, dbutils, spark
from data.config import DATA_DIR

# %%
# %%sql
#
# DESCRIBE DETAIL nytaxi_yellow_2
# Out:
#     <style>
#         .spark-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .spark-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .spark-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .spark-table tr:nth-child(even) { background-color: #fafafa; }
#         .spark-table tr:hover { background-color: #f0f0f0; }
#         .spark-info {
#             color: #666;
#             font-size: 12px;
#             margin-top: 8px;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#         }
#     </style>
#     <table class="spark-table">
#         <thead>
#             <tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th></tr>
#         </thead>
#         <tbody>
#             <tr><td>delta</td><td>7c7324f7-3859-4d9c-b0e6-57a204824a9e</td><td>spark_catalog.default.nytaxi_yellow_2</td><td>None</td><td>file:/opt/hive/data/warehouse/nytaxi_yellow_2</td><td>2025-12-09 14:52:39.619000</td><td>2025-12-09 14:53:06.107000</td><td>[]</td><td>[]</td><td>3</td><td>158048473</td><td>{}</td><td>1</td><td>2</td><td>['appendOnly', 'invariants']</td></tr>
#         </tbody>
#     </table>
#     <div class="spark-info">Showing 1 of 1 rows</div>

# %%
# %fs ls /user/hive/warehouse/nytaxi_yellow_2
# Out:
#     <style>
#         .fs-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .fs-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .fs-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .fs-table tr:nth-child(even) { background-color: #fafafa; }
#         .fs-table tr:hover { background-color: #f0f0f0; }
#     </style>
#     <table class="fs-table">
#         <thead>
#             <tr>
#                 <th>path</th>
#                 <th>name</th>
#                 <th>size</th>
#                 <th>modificationTime</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet.crc</td>
#                 <td>.part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet.crc</td>
#                 <td>412020</td>
#                 <td>1765291985546</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet.crc</td>
#                 <td>.part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet.crc</td>
#                 <td>411440</td>
#                 <td>1765291978480</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet.crc</td>
#                 <td>.part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet.crc</td>
#                 <td>411320</td>
#                 <td>1765291974973</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/_delta_log</td>
#                 <td>_delta_log/</td>
#                 <td>0</td>
#                 <td>1765291986123</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet</td>
#                 <td>part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet</td>
#                 <td>52737436</td>
#                 <td>1765291985546</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet</td>
#                 <td>part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet</td>
#                 <td>52663288</td>
#                 <td>1765291978480</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet</td>
#                 <td>part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet</td>
#                 <td>52647749</td>
#                 <td>1765291974973</td>
#             </tr>
#         </tbody>
#     </table>

# %%
# %%sql
#
# OPTIMIZE nytaxi_yellow_2 ZORDER BY Payment_Type
# Out:
#     <style>
#         .spark-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .spark-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .spark-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .spark-table tr:nth-child(even) { background-color: #fafafa; }
#         .spark-table tr:hover { background-color: #f0f0f0; }
#         .spark-info {
#             color: #666;
#             font-size: 12px;
#             margin-top: 8px;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#         }
#     </style>
#     <table class="spark-table">
#         <thead>
#             <tr><th>path</th><th>metrics</th></tr>
#         </thead>
#         <tbody>
#             <tr><td>file:/opt/hive/data/warehouse/nytaxi_yellow_2</td><td>Row(numFilesAdded=1, numFilesRemoved=3, filesAdded=Row(min=158094857, max=158094857, avg=158094857.0, totalFiles=1, totalSize=158094857), filesRemoved=Row(min=52647749, max=52737436, avg=52682824.333333336, totalFiles=3, totalSize=158048473), partitionsOptimized=1, zOrderStats=Row(strategyName='all', inputCubeFiles=Row(num=0, size=0), inputOtherFiles=Row(num=3, size=158048473), inputNumCubes=0, mergedFiles=Row(num=3, size=158048473), numOutputCubes=1, mergedNumCubes=None), clusteringStats=None, numBatches=1, totalConsideredFiles=3, totalFilesSkipped=0, preserveInsertionOrder=False, numFilesSkippedToReduceWriteAmplification=0, numBytesSkippedToReduceWriteAmplification=0, startTimeMs=1765292075454, endTimeMs=0, totalClusterParallelism=14, totalScheduledTasks=0, autoCompactParallelismStats=None, deletionVectorStats=None, numTableColumns=45, numTableColumnsWithStats=32)</td></tr>
#         </tbody>
#     </table>
#     <div class="spark-info">Showing 1 of 1 rows</div>

# %%
# %%sql
#
# DESCRIBE DETAIL nytaxi_yellow_2
# Out:
#     <style>
#         .spark-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .spark-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .spark-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .spark-table tr:nth-child(even) { background-color: #fafafa; }
#         .spark-table tr:hover { background-color: #f0f0f0; }
#         .spark-info {
#             color: #666;
#             font-size: 12px;
#             margin-top: 8px;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#         }
#     </style>
#     <table class="spark-table">
#         <thead>
#             <tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th></tr>
#         </thead>
#         <tbody>
#             <tr><td>delta</td><td>7c7324f7-3859-4d9c-b0e6-57a204824a9e</td><td>spark_catalog.default.nytaxi_yellow_2</td><td>None</td><td>file:/opt/hive/data/warehouse/nytaxi_yellow_2</td><td>2025-12-09 14:52:39.619000</td><td>2025-12-09 14:54:35.343000</td><td>[]</td><td>[]</td><td>1</td><td>158094857</td><td>{}</td><td>1</td><td>2</td><td>['appendOnly', 'invariants']</td></tr>
#         </tbody>
#     </table>
#     <div class="spark-info">Showing 1 of 1 rows</div>

# %%
# %%sql
#
# DESCRIBE HISTORY nytaxi_yellow_2
# Out:
#     <style>
#         .spark-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .spark-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .spark-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .spark-table tr:nth-child(even) { background-color: #fafafa; }
#         .spark-table tr:hover { background-color: #f0f0f0; }
#         .spark-info {
#             color: #666;
#             font-size: 12px;
#             margin-top: 8px;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#         }
#     </style>
#     <table class="spark-table">
#         <thead>
#             <tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr>
#         </thead>
#         <tbody>
#             <tr><td>1</td><td>2025-12-09 14:54:35.343000</td><td>None</td><td>None</td><td>OPTIMIZE</td><td>{'predicate': '[]', 'auto': 'false', 'zOrderBy': '["Payment_Type"]', 'clusterBy': '[]'}</td><td>None</td><td>None</td><td>None</td><td>0.0</td><td>SnapshotIsolation</td><td>False</td><td>{'numRemovedBytes': '158048473', 'p50FileSize': '158094857', 'p25FileSize': '158094857', 'numAddedFiles': '1', 'minFileSize': '158094857', 'p75FileSize': '158094857', 'numDeletionVectorsRemoved': '0', 'numAddedBytes': '158094857', 'maxFileSize': '158094857', 'numRemovedFiles': '3'}</td><td>None</td><td>Apache-Spark/3.5.3 Delta-Lake/3.2.0</td></tr><tr><td>0</td><td>2025-12-09 14:53:06.107000</td><td>None</td><td>None</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>{'partitionBy': '[]', 'description': None, 'properties': '{}', 'clusterBy': '[]', 'isManaged': 'true'}</td><td>None</td><td>None</td><td>None</td><td>nan</td><td>Serializable</td><td>False</td><td>{'numOutputRows': '3000317', 'numOutputBytes': '158048473', 'numFiles': '3'}</td><td>None</td><td>Apache-Spark/3.5.3 Delta-Lake/3.2.0</td></tr>
#         </tbody>
#     </table>
#     <div class="spark-info">Showing 2 of 2 rows</div>

# %%
# %fs ls /user/hive/warehouse/nytaxi_yellow_2
# Out:
#     <style>
#         .fs-table {
#             border-collapse: collapse;
#             font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#             font-size: 13px;
#         }
#         .fs-table th {
#             background-color: #f5f5f5;
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#             text-align: left;
#             font-weight: 600;
#         }
#         .fs-table td {
#             border: 1px solid #ddd;
#             padding: 8px 12px;
#         }
#         .fs-table tr:nth-child(even) { background-color: #fafafa; }
#         .fs-table tr:hover { background-color: #f0f0f0; }
#     </style>
#     <table class="fs-table">
#         <thead>
#             <tr>
#                 <th>path</th>
#                 <th>name</th>
#                 <th>size</th>
#                 <th>modificationTime</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00000-0f07c898-779d-4fec-bcaf-fc34c8c4b908-c000.snappy.parquet.crc</td>
#                 <td>.part-00000-0f07c898-779d-4fec-bcaf-fc34c8c4b908-c000.snappy.parquet.crc</td>
#                 <td>1235128</td>
#                 <td>1765292075273</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet.crc</td>
#                 <td>.part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet.crc</td>
#                 <td>412020</td>
#                 <td>1765291985546</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet.crc</td>
#                 <td>.part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet.crc</td>
#                 <td>411440</td>
#                 <td>1765291978480</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/.part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet.crc</td>
#                 <td>.part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet.crc</td>
#                 <td>411320</td>
#                 <td>1765291974973</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/_delta_log</td>
#                 <td>_delta_log/</td>
#                 <td>0</td>
#                 <td>1765292075353</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00000-0f07c898-779d-4fec-bcaf-fc34c8c4b908-c000.snappy.parquet</td>
#                 <td>part-00000-0f07c898-779d-4fec-bcaf-fc34c8c4b908-c000.snappy.parquet</td>
#                 <td>158094857</td>
#                 <td>1765292075273</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet</td>
#                 <td>part-00000-c7f86606-6d71-4c5d-8eb8-8dd6dbc66990-c000.snappy.parquet</td>
#                 <td>52737436</td>
#                 <td>1765291985546</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet</td>
#                 <td>part-00001-a3c25b65-4715-4299-b4f4-9804fa23992d-c000.snappy.parquet</td>
#                 <td>52663288</td>
#                 <td>1765291978480</td>
#             </tr>
#             <tr>
#                 <td>dbfs:/opt/hive/data/warehouse/nytaxi_yellow_2/part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet</td>
#                 <td>part-00002-be61a285-5371-42fb-8d05-239e06d12093-c000.snappy.parquet</td>
#                 <td>52647749</td>
#                 <td>1765291974973</td>
#             </tr>
#         </tbody>
#     </table>

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_2
WHERE Payment_Type = "Credit" 
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>5954194</td></tr><tr><td>VTS</td><td>6707165</td></tr></tbody></table></div>

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_2
WHERE Payment_Type = "Credit" 
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>5954194</td></tr><tr><td>VTS</td><td>6707165</td></tr></tbody></table></div>
